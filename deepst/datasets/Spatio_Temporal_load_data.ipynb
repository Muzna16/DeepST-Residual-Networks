# %%
from __future__ import print_function
import h5py
import time

# %%
fname='../../data/TaxiBJ/BJ13_M32x32_T30_InOut.h5'

# %%
f = h5py.File(fname, 'r')
# show attributes
for key in f.attrs.keys():
    print(key, f.attrs[key])
# show datasets
for key in f.keys():
    print(key, f[key].shape)
    # Assign datasets to variables
    data = f['data'][:]  # Use slicing to access the data
    timestamps = f['date'][:]
    
    print('data.shape',data.shape)
    print('Timestamp.shape',timestamps.shape)
    print(timestamps[0])

# Close the file when you're done
# f.close()

# Print some message after closing the file
print("This is load data from load_data.py")
# Out:
# data (4888, 2, 32, 32)
# data.shape (4888, 2, 32, 32)
# Timestamp.shape (4888,)
# b'2013070101'
# date (4888,)
# data.shape (4888, 2, 32, 32)
# Timestamp.shape (4888,)
# b'2013070101'
# This is load data from load_data.py

# %%
# show all the subgroups of the group 'data'
for key in f.keys():
    print(key, f[key].shape)
    # Assign datasets to variables
    data = f['data'][:]  # Use slicing to access the data
    timestamps = f['date'][:]
    
    print('data.shape',data.shape)
    print('Timestamp.shape',timestamps.shape)
    print(timestamps[0])
# Out:
# data (4888, 2, 32, 32)
# data.shape (4888, 2, 32, 32)
# Timestamp.shape (4888,)
# b'2013070101'
# date (4888,)
# data.shape (4888, 2, 32, 32)
# Timestamp.shape (4888,)
# b'2013070101'

# %%
# show f in plot 
import matplotlib.pyplot as plt
plt.plot(f['data'][:][0][0])
plt.plot(f['date'][:][0][1])
plt.show()
